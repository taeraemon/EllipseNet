# %%
import os
import sys
if '..' not in sys.path:
    sys.path.append('..')

import torch
import numpy as np
from torch.utils.data import DataLoader, Dataset
from torch import nn, optim
import argparse
from utiles import box2corners
from oriented_iou_loss import cal_diou, cal_giou

# %%
DATA = "./data"
X_MAX = 3
Y_MAX = 3
SCALE = 0.5
BATCH_SIZE = 32
N_DATA = 128
NUM_TRAIN = 200 * BATCH_SIZE * N_DATA
NUM_TEST = 20 * BATCH_SIZE * N_DATA

NUM_EPOCH = 20

if not os.path.exists(DATA):
    os.mkdir(DATA)

# %%
def create_data(num):
    print("... generating %d boxes, please wait..."%num)
    x = (np.random.rand(num) - 0.5) * 2 * X_MAX
    y = (np.random.rand(num) - 0.5) * 2 * Y_MAX
    w = (np.random.rand(num) - 0.5) * 2 * SCALE + 1
    h = (np.random.rand(num) - 0.5) * 2 * SCALE + 1
    alpha = np.random.rand(num) * np.pi
    corners = np.zeros((num, 4, 2)).astype(np.float)
    for i in range(num):
        corners[i, ...] = box2corners(x[i], y[i], w[i], h[i], alpha[i])
    label = np.stack([x, y , w, h, alpha], axis=1)
    return corners, label

def save_dataset():
    train_data, train_label = create_data(NUM_TRAIN)
    np.save(os.path.join(DATA, "train_data.npy"), train_data)
    np.save(os.path.join(DATA, "train_label.npy"), train_label)
    test_data, test_label = create_data(NUM_TEST)
    np.save(os.path.join(DATA, "test_data.npy"), test_data)
    np.save(os.path.join(DATA, "test_label.npy"), test_label)
    print("data saved in: ", DATA)

class BoxDataSet(Dataset):
    def __init__(self, split="train"):
        super(BoxDataSet, self).__init__()
        assert split in ["train", "test"], "split must be train or test"
        self.split = split
        try:
            self.data = np.load(os.path.join(DATA, split+"_data.npy"))
            self.label = np.load(os.path.join(DATA, split+"_label.npy"))
        except:
            save_dataset()
            self.data = np.load(os.path.join(DATA, split+"_data.npy"))
            self.label = np.load(os.path.join(DATA, split+"_label.npy"))
    def __len__(self) -> int:
        return self.data.shape[0]
    def __getitem__(self, index: int) :
        d = self.data[index, ...]
        l = self.label[index, ...]
        return torch.FloatTensor(d), torch.FloatTensor(l)

# %%
def create_network():
    return nn.Sequential(nn.Conv1d(8, 128, 1, bias=False),
                nn.BatchNorm1d(128),
                nn.ReLU(True),
                nn.Conv1d(128, 512, 1, bias=False),
                nn.BatchNorm1d(512),
                nn.ReLU(True),
                nn.Conv1d(512, 128, 1, bias=False),
                nn.BatchNorm1d(128),
                nn.ReLU(True),
                nn.Conv1d(128, 5, 1),
                nn.Sigmoid())

def parse_pred(pred:torch.Tensor):
    p0 = (pred[..., 0] - 0.5) * 2 * X_MAX
    p1 = (pred[..., 1] - 0.5) * 2 * Y_MAX
    p2 = (pred[..., 2] - 0.5) * 2 * SCALE + 1
    p3 = (pred[..., 3] - 0.5) * 2 * SCALE + 1
    p4 = pred[..., 4] * np.pi
    return torch.stack([p0,p1,p2,p3,p4], dim=-1)

# %%
def main(loss_type:str="giou", enclosing_type:str="aligned"):
    ds_train = BoxDataSet("train")
    ds_test = BoxDataSet("test")
    ld_train = DataLoader(ds_train, BATCH_SIZE * N_DATA, shuffle=True, num_workers=4)
    ld_test = DataLoader(ds_test, BATCH_SIZE * N_DATA, shuffle=False, num_workers=4)
    
    net = create_network()
    net.to("cuda:0")
    optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    num_batch = len(ds_train)//(BATCH_SIZE*N_DATA)
    
    for epoch in range(1, NUM_EPOCH+1):
        # train
        net.train()
        for i, data in enumerate(ld_train, 1):
            box, label = data
            box = box.cuda()                            # (B*N, 4, 2)
            box = box.view([BATCH_SIZE, -1, 4*2])       # (B, N, 4*2)
            box = box.transpose(1, 2)                   # (B, 8, N)
            label = label.cuda()                        # (B*N, 5)
            label = label.view([BATCH_SIZE, -1, 5])     # (B, N, 5)
            
            optimizer.zero_grad()
            pred = net(box)                             # (B, 5, N)
            pred = pred.transpose(1,2)                  # (B, N, 5)
            pred = parse_pred(pred)

            iou_loss, iou = None, None
            if loss_type == "giou":
                iou_loss, iou = cal_giou(pred, label, enclosing_type)
            elif loss_type == "diou":
                iou_loss, iou = cal_diou(pred, label, enclosing_type)
            else:
                ValueError("unknown loss type")
            iou_loss = torch.mean(iou_loss)
            iou_loss.backward()
            optimizer.step()

            if i%10 == 0:
                iou_mask = (iou > 0).float()
                mean_iou = torch.sum(iou) / (torch.sum(iou_mask) + 1e-8)
                print("[Epoch %d: %d/%d] train loss: %.4f  mean_iou: %.4f"
                    %(epoch, i, num_batch, iou_loss.detach().cpu().item(), mean_iou.detach().cpu().item()))
        lr_scheduler.step()

        # validate
        net.eval()
        aver_loss = 0
        aver_mean_iou = 0
        with torch.no_grad():
            for i, data in enumerate(ld_test, 1):
                box, label = data
                box = box.cuda()                            # (B*N, 4, 2)
                box = box.view([BATCH_SIZE, -1, 4*2])       # (B, N, 4*2)
                box = box.transpose(1, 2)                   # (B, 8, N)
                label = label.cuda()                        # (B*N, 5)
                label = label.view([BATCH_SIZE, -1, 5])     # (B, N, 5)
                
                pred = net(box)                             # (B, 5, N)
                pred = pred.transpose(1,2)                  # (B, N, 5)
                pred = parse_pred(pred)

                iou_loss, iou = None, None
                if loss_type == "giou":
                    iou_loss, iou = cal_giou(pred, label, enclosing_type)
                elif loss_type == "diou":
                    iou_loss, iou = cal_diou(pred, label, enclosing_type)
                else:
                    ValueError("unknown loss type")
                iou_loss = torch.mean(iou_loss)
                aver_loss += iou_loss.cpu().item()
                iou_mask = (iou > 0).float()
                mean_iou = torch.sum(iou) / (torch.sum(iou_mask) + 1e-8)
                aver_mean_iou += mean_iou.cpu().item()
        print("... validate epoch %d ..."%epoch)
        n_iter = len(ds_test)/BATCH_SIZE/N_DATA
        print("average loss: %.4f"%(aver_loss/n_iter))
        print("average iou: %.4f"%(aver_mean_iou/n_iter))
        print("..............................")

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--loss", type=str, default="diou", help="type of loss function. support: diou or giou. [default: diou]")
parser.add_argument("--enclosing", type=str, default="smallest", 
    help="type of enclosing box. support: aligned (axis-aligned) or pca (rotated) or smallest (rotated). [default: smallest]")
flags = parser.parse_args([])
main(flags.loss, flags.enclosing)
# Out:
# ... generating 819200 boxes, please wait...
# ... generating 81920 boxes, please wait...
# data saved in:  ./data
# [Epoch 1: 10/200] train loss: 0.6570  mean_iou: 0.3814
# [Epoch 1: 20/200] train loss: 0.5029  mean_iou: 0.5106
# [Epoch 1: 30/200] train loss: 0.4490  mean_iou: 0.5581
# [Epoch 1: 40/200] train loss: 0.4389  mean_iou: 0.5680
# [Epoch 1: 50/200] train loss: 0.4135  mean_iou: 0.5910
# [Epoch 1: 60/200] train loss: 0.4179  mean_iou: 0.5879
# [Epoch 1: 70/200] train loss: 0.4249  mean_iou: 0.5827
# [Epoch 1: 80/200] train loss: 0.4280  mean_iou: 0.5803
# [Epoch 1: 90/200] train loss: 0.3796  mean_iou: 0.6244
# [Epoch 1: 100/200] train loss: 0.3888  mean_iou: 0.6174
# [Epoch 1: 110/200] train loss: 0.3506  mean_iou: 0.6527
# [Epoch 1: 120/200] train loss: 0.3598  mean_iou: 0.6450
# [Epoch 1: 130/200] train loss: 0.4119  mean_iou: 0.5988
# [Epoch 1: 140/200] train loss: 0.3848  mean_iou: 0.6230
# [Epoch 1: 150/200] train loss: 0.4175  mean_iou: 0.5945
# [Epoch 1: 160/200] train loss: 0.3684  mean_iou: 0.6382
# [Epoch 1: 170/200] train loss: 0.3532  mean_iou: 0.6518
# [Epoch 1: 180/200] train loss: 0.3843  mean_iou: 0.6241
# [Epoch 1: 190/200] train loss: 0.3561  mean_iou: 0.6501
# [Epoch 1: 200/200] train loss: 0.3459  mean_iou: 0.6598
# ... validate epoch 1 ...
# average loss: 0.3515
# average iou: 0.6548
# ..............................
# [Epoch 2: 10/200] train loss: 0.3817  mean_iou: 0.6274
# [Epoch 2: 20/200] train loss: 0.3371  mean_iou: 0.6689
# [Epoch 2: 30/200] train loss: 0.3172  mean_iou: 0.6871
# [Epoch 2: 40/200] train loss: 0.3007  mean_iou: 0.7024
# [Epoch 2: 50/200] train loss: 0.4187  mean_iou: 0.5943
# [Epoch 2: 60/200] train loss: 0.3543  mean_iou: 0.6541
# [Epoch 2: 70/200] train loss: 0.3077  mean_iou: 0.6974
# [Epoch 2: 80/200] train loss: 0.3135  mean_iou: 0.6920
# [Epoch 2: 90/200] train loss: 0.2802  mean_iou: 0.7231
# [Epoch 2: 100/200] train loss: 0.3184  mean_iou: 0.6879
# [Epoch 2: 110/200] train loss: 0.3856  mean_iou: 0.6263
# [Epoch 2: 120/200] train loss: 0.3221  mean_iou: 0.6849
# [Epoch 2: 130/200] train loss: 0.3558  mean_iou: 0.6535
# [Epoch 2: 140/200] train loss: 0.3690  mean_iou: 0.6415
# [Epoch 2: 150/200] train loss: 0.3319  mean_iou: 0.6760
# [Epoch 2: 160/200] train loss: 0.2850  mean_iou: 0.7190
# [Epoch 2: 170/200] train loss: 0.3546  mean_iou: 0.6551
# [Epoch 2: 180/200] train loss: 0.3736  mean_iou: 0.6374
# [Epoch 2: 190/200] train loss: 0.3568  mean_iou: 0.6527
# [Epoch 2: 200/200] train loss: 0.3866  mean_iou: 0.6263
# ... validate epoch 2 ...
# average loss: 0.3000
# average iou: 0.7064
# ..............................
# [Epoch 3: 10/200] train loss: 0.3242  mean_iou: 0.6832
# [Epoch 3: 20/200] train loss: 0.4593  mean_iou: 0.5597
# [Epoch 3: 30/200] train loss: 0.3375  mean_iou: 0.6698
# [Epoch 3: 40/200] train loss: 0.3929  mean_iou: 0.6206
# [Epoch 3: 50/200] train loss: 0.3437  mean_iou: 0.6647
# [Epoch 3: 60/200] train loss: 0.2854  mean_iou: 0.7197
# [Epoch 3: 70/200] train loss: 0.3194  mean_iou: 0.6880
# [Epoch 3: 80/200] train loss: 0.3113  mean_iou: 0.6955
# [Epoch 3: 90/200] train loss: 0.3275  mean_iou: 0.6812
# [Epoch 3: 100/200] train loss: 0.4332  mean_iou: 0.5836
# [Epoch 3: 110/200] train loss: 0.3225  mean_iou: 0.6852
# [Epoch 3: 120/200] train loss: 0.2877  mean_iou: 0.7176
# [Epoch 3: 130/200] train loss: 0.3813  mean_iou: 0.6313
# [Epoch 3: 140/200] train loss: 0.3497  mean_iou: 0.6604
# [Epoch 3: 150/200] train loss: 0.3427  mean_iou: 0.6663
# [Epoch 3: 160/200] train loss: 0.2867  mean_iou: 0.7189
# [Epoch 3: 170/200] train loss: 0.2933  mean_iou: 0.7128
# [Epoch 3: 180/200] train loss: 0.3301  mean_iou: 0.6782
# [Epoch 3: 190/200] train loss: 0.2909  mean_iou: 0.7148
# [Epoch 3: 200/200] train loss: 0.3287  mean_iou: 0.6802
# ... validate epoch 3 ...
# average loss: 0.2968
# average iou: 0.7099
# ..............................
# [Epoch 4: 10/200] train loss: 0.4414  mean_iou: 0.5756
# [Epoch 4: 20/200] train loss: 0.3645  mean_iou: 0.6468
# [Epoch 4: 30/200] train loss: 0.2850  mean_iou: 0.7200
# [Epoch 4: 40/200] train loss: 0.2774  mean_iou: 0.7282
# [Epoch 4: 50/200] train loss: 0.2550  mean_iou: 0.7489
# [Epoch 4: 60/200] train loss: 0.2708  mean_iou: 0.7341
# [Epoch 4: 70/200] train loss: 0.2699  mean_iou: 0.7349
# [Epoch 4: 80/200] train loss: 0.2856  mean_iou: 0.7204
# [Epoch 4: 90/200] train loss: 0.3431  mean_iou: 0.6667
# [Epoch 4: 100/200] train loss: 0.2744  mean_iou: 0.7311
# [Epoch 4: 110/200] train loss: 0.2648  mean_iou: 0.7404
# [Epoch 4: 120/200] train loss: 0.2645  mean_iou: 0.7406
# [Epoch 4: 130/200] train loss: 0.2253  mean_iou: 0.7776
# [Epoch 4: 140/200] train loss: 0.2825  mean_iou: 0.7231
# [Epoch 4: 150/200] train loss: 0.3988  mean_iou: 0.6161
# [Epoch 4: 160/200] train loss: 0.3016  mean_iou: 0.7057
# [Epoch 4: 170/200] train loss: 0.3240  mean_iou: 0.6837
# [Epoch 4: 180/200] train loss: 0.4013  mean_iou: 0.6138
# [Epoch 4: 190/200] train loss: 0.3149  mean_iou: 0.6927
# [Epoch 4: 200/200] train loss: 0.2344  mean_iou: 0.7688
# ... validate epoch 4 ...
# average loss: 0.2809
# average iou: 0.7258
# ..............................
# [Epoch 5: 10/200] train loss: 0.2442  mean_iou: 0.7598
# [Epoch 5: 20/200] train loss: 0.3113  mean_iou: 0.6972
# [Epoch 5: 30/200] train loss: 0.2774  mean_iou: 0.7281
# [Epoch 5: 40/200] train loss: 0.4667  mean_iou: 0.5560
# [Epoch 5: 50/200] train loss: 0.3947  mean_iou: 0.6208
# [Epoch 5: 60/200] train loss: 0.3382  mean_iou: 0.6710
# [Epoch 5: 70/200] train loss: 0.2938  mean_iou: 0.7139
# [Epoch 5: 80/200] train loss: 0.3134  mean_iou: 0.6950
# [Epoch 5: 90/200] train loss: 0.4168  mean_iou: 0.6012
# [Epoch 5: 100/200] train loss: 0.3273  mean_iou: 0.6808
# [Epoch 5: 110/200] train loss: 0.3183  mean_iou: 0.6897
# [Epoch 5: 120/200] train loss: 0.2916  mean_iou: 0.7149
# [Epoch 5: 130/200] train loss: 0.2401  mean_iou: 0.7635
# [Epoch 5: 140/200] train loss: 0.2881  mean_iou: 0.7186
# [Epoch 5: 150/200] train loss: 0.2365  mean_iou: 0.7673
# [Epoch 5: 160/200] train loss: 0.2462  mean_iou: 0.7584
# [Epoch 5: 170/200] train loss: 0.2883  mean_iou: 0.7184
# [Epoch 5: 180/200] train loss: 0.3567  mean_iou: 0.6539
# [Epoch 5: 190/200] train loss: 0.2558  mean_iou: 0.7487
# [Epoch 5: 200/200] train loss: 0.3290  mean_iou: 0.6811
# ... validate epoch 5 ...
# average loss: 0.2815
# average iou: 0.7266
# ..............................
# [Epoch 6: 10/200] train loss: 0.2657  mean_iou: 0.7406
# [Epoch 6: 20/200] train loss: 0.2865  mean_iou: 0.7205
# [Epoch 6: 30/200] train loss: 0.2597  mean_iou: 0.7464
# [Epoch 6: 40/200] train loss: 0.2820  mean_iou: 0.7248
# [Epoch 6: 50/200] train loss: 0.3218  mean_iou: 0.6890
# [Epoch 6: 60/200] train loss: 0.2531  mean_iou: 0.7523
# [Epoch 6: 70/200] train loss: 0.2594  mean_iou: 0.7456
# [Epoch 6: 80/200] train loss: 0.2829  mean_iou: 0.7234
# [Epoch 6: 90/200] train loss: 0.2752  mean_iou: 0.7306
# [Epoch 6: 100/200] train loss: 0.3037  mean_iou: 0.7043
# [Epoch 6: 110/200] train loss: 0.2512  mean_iou: 0.7531
# [Epoch 6: 120/200] train loss: 0.3392  mean_iou: 0.6714
# [Epoch 6: 130/200] train loss: 0.2835  mean_iou: 0.7232
# [Epoch 6: 140/200] train loss: 0.3112  mean_iou: 0.6976
# [Epoch 6: 150/200] train loss: 0.3214  mean_iou: 0.6882
# [Epoch 6: 160/200] train loss: 0.3387  mean_iou: 0.6713
# [Epoch 6: 170/200] train loss: 0.3033  mean_iou: 0.7051
# [Epoch 6: 180/200] train loss: 0.2292  mean_iou: 0.7746
# [Epoch 6: 190/200] train loss: 0.2828  mean_iou: 0.7244
# [Epoch 6: 200/200] train loss: 0.3336  mean_iou: 0.6767
# ... validate epoch 6 ...
# average loss: 0.2467
# average iou: 0.7580
# ..............................
# [Epoch 7: 10/200] train loss: 0.3256  mean_iou: 0.6838
# [Epoch 7: 20/200] train loss: 0.3512  mean_iou: 0.6605
# [Epoch 7: 30/200] train loss: 0.2241  mean_iou: 0.7794
# [Epoch 7: 40/200] train loss: 0.2291  mean_iou: 0.7741
# [Epoch 7: 50/200] train loss: 0.2530  mean_iou: 0.7521
# [Epoch 7: 60/200] train loss: 0.4363  mean_iou: 0.5842
# [Epoch 7: 70/200] train loss: 0.2447  mean_iou: 0.7609
# [Epoch 7: 80/200] train loss: 0.3204  mean_iou: 0.6889
# [Epoch 7: 90/200] train loss: 0.2436  mean_iou: 0.7605
# [Epoch 7: 100/200] train loss: 0.3611  mean_iou: 0.6517
# [Epoch 7: 110/200] train loss: 0.2902  mean_iou: 0.7169
# [Epoch 7: 120/200] train loss: 0.2081  mean_iou: 0.7950
# [Epoch 7: 130/200] train loss: 0.2992  mean_iou: 0.7083
# [Epoch 7: 140/200] train loss: 0.2386  mean_iou: 0.7663
# [Epoch 7: 150/200] train loss: 0.2872  mean_iou: 0.7203
# [Epoch 7: 160/200] train loss: 0.3627  mean_iou: 0.6496
# [Epoch 7: 170/200] train loss: 0.3723  mean_iou: 0.6414
# [Epoch 7: 180/200] train loss: 0.2888  mean_iou: 0.7181
# [Epoch 7: 190/200] train loss: 0.2551  mean_iou: 0.7504
# [Epoch 7: 200/200] train loss: 0.3012  mean_iou: 0.7067
# ... validate epoch 7 ...
# average loss: 0.3280
# average iou: 0.6830
# ..............................
# [Epoch 8: 10/200] train loss: 0.5161  mean_iou: 0.5107
# [Epoch 8: 20/200] train loss: 0.3308  mean_iou: 0.6788
# [Epoch 8: 30/200] train loss: 0.4051  mean_iou: 0.6104
# [Epoch 8: 40/200] train loss: 0.2241  mean_iou: 0.7799
# [Epoch 8: 50/200] train loss: 0.2678  mean_iou: 0.7384
# [Epoch 8: 60/200] train loss: 0.2064  mean_iou: 0.7969
# [Epoch 8: 70/200] train loss: 0.2512  mean_iou: 0.7544
# [Epoch 8: 80/200] train loss: 0.3026  mean_iou: 0.7062
# [Epoch 8: 90/200] train loss: 0.2884  mean_iou: 0.7186
# [Epoch 8: 100/200] train loss: 0.3721  mean_iou: 0.6408
# [Epoch 8: 110/200] train loss: 0.3391  mean_iou: 0.6710
# [Epoch 8: 120/200] train loss: 0.2536  mean_iou: 0.7518
# [Epoch 8: 130/200] train loss: 0.2490  mean_iou: 0.7562
# [Epoch 8: 140/200] train loss: 0.3302  mean_iou: 0.6796
# [Epoch 8: 150/200] train loss: 0.3362  mean_iou: 0.6753
# [Epoch 8: 160/200] train loss: 0.3780  mean_iou: 0.6371
# [Epoch 8: 170/200] train loss: 0.2507  mean_iou: 0.7552
# [Epoch 8: 180/200] train loss: 0.3149  mean_iou: 0.6935
# [Epoch 8: 190/200] train loss: 0.3304  mean_iou: 0.6794
# [Epoch 8: 200/200] train loss: 0.2501  mean_iou: 0.7558
# ... validate epoch 8 ...
# average loss: 0.3262
# average iou: 0.6845
# ..............................
# [Epoch 9: 10/200] train loss: 0.3694  mean_iou: 0.6441
# [Epoch 9: 20/200] train loss: 0.3690  mean_iou: 0.6442
# [Epoch 9: 30/200] train loss: 0.3613  mean_iou: 0.6518
# [Epoch 9: 40/200] train loss: 0.3613  mean_iou: 0.6519
# [Epoch 9: 50/200] train loss: 0.1935  mean_iou: 0.8092
# [Epoch 9: 60/200] train loss: 0.3118  mean_iou: 0.6967
# [Epoch 9: 70/200] train loss: 0.3022  mean_iou: 0.7071
# [Epoch 9: 80/200] train loss: 0.3330  mean_iou: 0.6769
# [Epoch 9: 90/200] train loss: 0.2227  mean_iou: 0.7812
# [Epoch 9: 100/200] train loss: 0.3244  mean_iou: 0.6849
# [Epoch 9: 110/200] train loss: 0.2881  mean_iou: 0.7193
# [Epoch 9: 120/200] train loss: 0.3601  mean_iou: 0.6512
# [Epoch 9: 130/200] train loss: 0.3684  mean_iou: 0.6436
# [Epoch 9: 140/200] train loss: 0.4039  mean_iou: 0.6113
# [Epoch 9: 150/200] train loss: 0.2754  mean_iou: 0.7311
# [Epoch 9: 160/200] train loss: 0.1770  mean_iou: 0.8249
# [Epoch 9: 170/200] train loss: 0.2006  mean_iou: 0.8025
# [Epoch 9: 180/200] train loss: 0.3522  mean_iou: 0.6593
# [Epoch 9: 190/200] train loss: 0.2091  mean_iou: 0.7942
# [Epoch 9: 200/200] train loss: 0.2397  mean_iou: 0.7649
# ... validate epoch 9 ...
# average loss: 0.2337
# average iou: 0.7720
# ..............................
# [Epoch 10: 10/200] train loss: 0.2276  mean_iou: 0.7767
# [Epoch 10: 20/200] train loss: 0.1918  mean_iou: 0.8110
# [Epoch 10: 30/200] train loss: 0.3921  mean_iou: 0.6230
# [Epoch 10: 40/200] train loss: 0.1873  mean_iou: 0.8152
# [Epoch 10: 50/200] train loss: 0.3112  mean_iou: 0.6970
# [Epoch 10: 60/200] train loss: 0.2639  mean_iou: 0.7423
# [Epoch 10: 70/200] train loss: 0.3020  mean_iou: 0.7055
# [Epoch 10: 80/200] train loss: 0.2271  mean_iou: 0.7771
# [Epoch 10: 90/200] train loss: 0.2193  mean_iou: 0.7847
# [Epoch 10: 100/200] train loss: 0.3400  mean_iou: 0.6702
# [Epoch 10: 110/200] train loss: 0.2747  mean_iou: 0.7316
# [Epoch 10: 120/200] train loss: 0.2030  mean_iou: 0.8001
# [Epoch 10: 130/200] train loss: 0.2870  mean_iou: 0.7206
# [Epoch 10: 140/200] train loss: 0.2081  mean_iou: 0.7952
# [Epoch 10: 150/200] train loss: 0.2227  mean_iou: 0.7809
# [Epoch 10: 160/200] train loss: 0.2707  mean_iou: 0.7364
# [Epoch 10: 170/200] train loss: 0.3130  mean_iou: 0.6949
# [Epoch 10: 180/200] train loss: 0.2637  mean_iou: 0.7422
# [Epoch 10: 190/200] train loss: 0.2056  mean_iou: 0.7975
# [Epoch 10: 200/200] train loss: 0.1971  mean_iou: 0.8059
# ... validate epoch 10 ...
# average loss: 0.2326
# average iou: 0.7715
# ..............................
# [Epoch 11: 10/200] train loss: 0.2093  mean_iou: 0.7943
# [Epoch 11: 20/200] train loss: 0.1356  mean_iou: 0.8655
# [Epoch 11: 30/200] train loss: 0.1940  mean_iou: 0.8087
# [Epoch 11: 40/200] train loss: 0.1762  mean_iou: 0.8260
# [Epoch 11: 50/200] train loss: 0.1695  mean_iou: 0.8325
# [Epoch 11: 60/200] train loss: 0.1525  mean_iou: 0.8490
# [Epoch 11: 70/200] train loss: 0.2283  mean_iou: 0.7759
# [Epoch 11: 80/200] train loss: 0.2643  mean_iou: 0.7413
# [Epoch 11: 90/200] train loss: 0.2262  mean_iou: 0.7779
# [Epoch 11: 100/200] train loss: 0.1237  mean_iou: 0.8771
# [Epoch 11: 110/200] train loss: 0.1852  mean_iou: 0.8175
# [Epoch 11: 120/200] train loss: 0.1563  mean_iou: 0.8452
# [Epoch 11: 130/200] train loss: 0.2443  mean_iou: 0.7607
# [Epoch 11: 140/200] train loss: 0.1811  mean_iou: 0.8212
# [Epoch 11: 150/200] train loss: 0.1773  mean_iou: 0.8250
# [Epoch 11: 160/200] train loss: 0.2232  mean_iou: 0.7805
# [Epoch 11: 170/200] train loss: 0.1866  mean_iou: 0.8159
# [Epoch 11: 180/200] train loss: 0.1837  mean_iou: 0.8187
# [Epoch 11: 190/200] train loss: 0.1457  mean_iou: 0.8557
# [Epoch 11: 200/200] train loss: 0.1612  mean_iou: 0.8405
# ... validate epoch 11 ...
# average loss: 0.1190
# average iou: 0.8818
# ..............................
# [Epoch 12: 10/200] train loss: 0.1428  mean_iou: 0.8586
# [Epoch 12: 20/200] train loss: 0.1504  mean_iou: 0.8511
# [Epoch 12: 30/200] train loss: 0.1695  mean_iou: 0.8324
# [Epoch 12: 40/200] train loss: 0.1958  mean_iou: 0.8071
# [Epoch 12: 50/200] train loss: 0.1514  mean_iou: 0.8501
# [Epoch 12: 60/200] train loss: 0.2455  mean_iou: 0.7592
# [Epoch 12: 70/200] train loss: 0.1852  mean_iou: 0.8173
# [Epoch 12: 80/200] train loss: 0.1701  mean_iou: 0.8320
# [Epoch 12: 90/200] train loss: 0.1222  mean_iou: 0.8786
# [Epoch 12: 100/200] train loss: 0.1670  mean_iou: 0.8350
# [Epoch 12: 110/200] train loss: 0.1478  mean_iou: 0.8534
# [Epoch 12: 120/200] train loss: 0.1690  mean_iou: 0.8330
# [Epoch 12: 130/200] train loss: 0.1804  mean_iou: 0.8220
# [Epoch 12: 140/200] train loss: 0.1670  mean_iou: 0.8349
# [Epoch 12: 150/200] train loss: 0.1192  mean_iou: 0.8815
# [Epoch 12: 160/200] train loss: 0.1951  mean_iou: 0.8078
# [Epoch 12: 170/200] train loss: 0.1514  mean_iou: 0.8503
# [Epoch 12: 180/200] train loss: 0.1529  mean_iou: 0.8488
# [Epoch 12: 190/200] train loss: 0.1330  mean_iou: 0.8681
# [Epoch 12: 200/200] train loss: 0.1529  mean_iou: 0.8487
# ... validate epoch 12 ...
# average loss: 0.1157
# average iou: 0.8850
# ..............................
# [Epoch 13: 10/200] train loss: 0.1252  mean_iou: 0.8757
# [Epoch 13: 20/200] train loss: 0.2185  mean_iou: 0.7853
# [Epoch 13: 30/200] train loss: 0.1559  mean_iou: 0.8459
# [Epoch 13: 40/200] train loss: 0.1475  mean_iou: 0.8539
# [Epoch 13: 50/200] train loss: 0.1514  mean_iou: 0.8501
# [Epoch 13: 60/200] train loss: 0.1626  mean_iou: 0.8392
# [Epoch 13: 70/200] train loss: 0.1483  mean_iou: 0.8532
# [Epoch 13: 80/200] train loss: 0.1282  mean_iou: 0.8728
# [Epoch 13: 90/200] train loss: 0.1598  mean_iou: 0.8419
# [Epoch 13: 100/200] train loss: 0.2023  mean_iou: 0.8007
# [Epoch 13: 110/200] train loss: 0.2211  mean_iou: 0.7826
# [Epoch 13: 120/200] train loss: 0.1825  mean_iou: 0.8199
# [Epoch 13: 130/200] train loss: 0.1472  mean_iou: 0.8543
# [Epoch 13: 140/200] train loss: 0.1839  mean_iou: 0.8186
# [Epoch 13: 150/200] train loss: 0.1557  mean_iou: 0.8462
# [Epoch 13: 160/200] train loss: 0.1372  mean_iou: 0.8639
# [Epoch 13: 170/200] train loss: 0.1762  mean_iou: 0.8262
# [Epoch 13: 180/200] train loss: 0.1465  mean_iou: 0.8550
# [Epoch 13: 190/200] train loss: 0.1652  mean_iou: 0.8367
# [Epoch 13: 200/200] train loss: 0.1466  mean_iou: 0.8548
# ... validate epoch 13 ...
# average loss: 0.1175
# average iou: 0.8833
# ..............................
# [Epoch 14: 10/200] train loss: 0.1364  mean_iou: 0.8648
# [Epoch 14: 20/200] train loss: 0.1994  mean_iou: 0.8037
# [Epoch 14: 30/200] train loss: 0.2466  mean_iou: 0.7583
# [Epoch 14: 40/200] train loss: 0.1425  mean_iou: 0.8589
# [Epoch 14: 50/200] train loss: 0.1579  mean_iou: 0.8438
# [Epoch 14: 60/200] train loss: 0.1380  mean_iou: 0.8631
# [Epoch 14: 70/200] train loss: 0.1395  mean_iou: 0.8618
# [Epoch 14: 80/200] train loss: 0.1454  mean_iou: 0.8560
# [Epoch 14: 90/200] train loss: 0.1836  mean_iou: 0.8189
# [Epoch 14: 100/200] train loss: 0.1550  mean_iou: 0.8467
# [Epoch 14: 110/200] train loss: 0.1465  mean_iou: 0.8549
# [Epoch 14: 120/200] train loss: 0.1665  mean_iou: 0.8356
# [Epoch 14: 130/200] train loss: 0.1784  mean_iou: 0.8240
# [Epoch 14: 140/200] train loss: 0.1548  mean_iou: 0.8468
# [Epoch 14: 150/200] train loss: 0.1288  mean_iou: 0.8722
# [Epoch 14: 160/200] train loss: 0.1558  mean_iou: 0.8459
# [Epoch 14: 170/200] train loss: 0.1769  mean_iou: 0.8254
# [Epoch 14: 180/200] train loss: 0.1891  mean_iou: 0.8136
# [Epoch 14: 190/200] train loss: 0.1311  mean_iou: 0.8699
# [Epoch 14: 200/200] train loss: 0.1438  mean_iou: 0.8576
# ... validate epoch 14 ...
# average loss: 0.1228
# average iou: 0.8781
# ..............................
# [Epoch 15: 10/200] train loss: 0.1907  mean_iou: 0.8121
# [Epoch 15: 20/200] train loss: 0.1352  mean_iou: 0.8660
# [Epoch 15: 30/200] train loss: 0.1419  mean_iou: 0.8594
# [Epoch 15: 40/200] train loss: 0.1268  mean_iou: 0.8741
# [Epoch 15: 50/200] train loss: 0.1733  mean_iou: 0.8287
# [Epoch 15: 60/200] train loss: 0.1590  mean_iou: 0.8428
# [Epoch 15: 70/200] train loss: 0.2037  mean_iou: 0.7996
# [Epoch 15: 80/200] train loss: 0.1333  mean_iou: 0.8677
# [Epoch 15: 90/200] train loss: 0.1756  mean_iou: 0.8267
# [Epoch 15: 100/200] train loss: 0.1827  mean_iou: 0.8197
# [Epoch 15: 110/200] train loss: 0.1687  mean_iou: 0.8334
# [Epoch 15: 120/200] train loss: 0.1805  mean_iou: 0.8219
# [Epoch 15: 130/200] train loss: 0.1591  mean_iou: 0.8427
# [Epoch 15: 140/200] train loss: 0.1401  mean_iou: 0.8611
# [Epoch 15: 150/200] train loss: 0.1288  mean_iou: 0.8721
# [Epoch 15: 160/200] train loss: 0.1564  mean_iou: 0.8455
# [Epoch 15: 170/200] train loss: 0.1921  mean_iou: 0.8109
# [Epoch 15: 180/200] train loss: 0.1676  mean_iou: 0.8344
# [Epoch 15: 190/200] train loss: 0.2067  mean_iou: 0.7965
# [Epoch 15: 200/200] train loss: 0.1556  mean_iou: 0.8462
# ... validate epoch 15 ...
# average loss: 0.1381
# average iou: 0.8632
# ..............................
# [Epoch 16: 10/200] train loss: 0.1470  mean_iou: 0.8545
# [Epoch 16: 20/200] train loss: 0.1407  mean_iou: 0.8605
# [Epoch 16: 30/200] train loss: 0.1424  mean_iou: 0.8588
# [Epoch 16: 40/200] train loss: 0.1686  mean_iou: 0.8335
# [Epoch 16: 50/200] train loss: 0.1794  mean_iou: 0.8229
# [Epoch 16: 60/200] train loss: 0.1323  mean_iou: 0.8687
# [Epoch 16: 70/200] train loss: 0.1308  mean_iou: 0.8701
# [Epoch 16: 80/200] train loss: 0.1567  mean_iou: 0.8451
# [Epoch 16: 90/200] train loss: 0.1543  mean_iou: 0.8474
# [Epoch 16: 100/200] train loss: 0.1697  mean_iou: 0.8323
# [Epoch 16: 110/200] train loss: 0.1788  mean_iou: 0.8238
# [Epoch 16: 120/200] train loss: 0.1826  mean_iou: 0.8199
# [Epoch 16: 130/200] train loss: 0.1547  mean_iou: 0.8470
# [Epoch 16: 140/200] train loss: 0.1471  mean_iou: 0.8544
# [Epoch 16: 150/200] train loss: 0.1585  mean_iou: 0.8434
# [Epoch 16: 160/200] train loss: 0.2483  mean_iou: 0.7565
# [Epoch 16: 170/200] train loss: 0.2008  mean_iou: 0.8024
# [Epoch 16: 180/200] train loss: 0.1543  mean_iou: 0.8474
# [Epoch 16: 190/200] train loss: 0.1512  mean_iou: 0.8504
# [Epoch 16: 200/200] train loss: 0.1929  mean_iou: 0.8098
# ... validate epoch 16 ...
# average loss: 0.1095
# average iou: 0.8912
# ..............................
# [Epoch 17: 10/200] train loss: 0.2053  mean_iou: 0.7980
# [Epoch 17: 20/200] train loss: 0.1399  mean_iou: 0.8613
# [Epoch 17: 30/200] train loss: 0.1406  mean_iou: 0.8606
# [Epoch 17: 40/200] train loss: 0.1728  mean_iou: 0.8293
# [Epoch 17: 50/200] train loss: 0.1399  mean_iou: 0.8613
# [Epoch 17: 60/200] train loss: 0.2059  mean_iou: 0.7973
# [Epoch 17: 70/200] train loss: 0.1629  mean_iou: 0.8391
# [Epoch 17: 80/200] train loss: 0.1671  mean_iou: 0.8350
# [Epoch 17: 90/200] train loss: 0.1421  mean_iou: 0.8592
# [Epoch 17: 100/200] train loss: 0.1388  mean_iou: 0.8625
# [Epoch 17: 110/200] train loss: 0.1624  mean_iou: 0.8395
# [Epoch 17: 120/200] train loss: 0.1712  mean_iou: 0.8310
# [Epoch 17: 130/200] train loss: 0.1577  mean_iou: 0.8442
# [Epoch 17: 140/200] train loss: 0.1784  mean_iou: 0.8240
# [Epoch 17: 150/200] train loss: 0.2485  mean_iou: 0.7563
# [Epoch 17: 160/200] train loss: 0.1297  mean_iou: 0.8714
# [Epoch 17: 170/200] train loss: 0.1674  mean_iou: 0.8347
# [Epoch 17: 180/200] train loss: 0.1883  mean_iou: 0.8143
# [Epoch 17: 190/200] train loss: 0.1286  mean_iou: 0.8725
# [Epoch 17: 200/200] train loss: 0.1297  mean_iou: 0.8714
# ... validate epoch 17 ...
# average loss: 0.1311
# average iou: 0.8701
# ..............................
# [Epoch 18: 10/200] train loss: 0.1434  mean_iou: 0.8579
# [Epoch 18: 20/200] train loss: 0.1744  mean_iou: 0.8278
# [Epoch 18: 30/200] train loss: 0.1282  mean_iou: 0.8728
# [Epoch 18: 40/200] train loss: 0.1403  mean_iou: 0.8610
# [Epoch 18: 50/200] train loss: 0.1590  mean_iou: 0.8429
# [Epoch 18: 60/200] train loss: 0.1452  mean_iou: 0.8563
# [Epoch 18: 70/200] train loss: 0.1567  mean_iou: 0.8450
# [Epoch 18: 80/200] train loss: 0.1363  mean_iou: 0.8649
# [Epoch 18: 90/200] train loss: 0.2041  mean_iou: 0.7991
# [Epoch 18: 100/200] train loss: 0.1426  mean_iou: 0.8589
# [Epoch 18: 110/200] train loss: 0.1312  mean_iou: 0.8698
# [Epoch 18: 120/200] train loss: 0.1776  mean_iou: 0.8248
# [Epoch 18: 130/200] train loss: 0.1336  mean_iou: 0.8675
# [Epoch 18: 140/200] train loss: 0.1854  mean_iou: 0.8173
# [Epoch 18: 150/200] train loss: 0.1416  mean_iou: 0.8597
# [Epoch 18: 160/200] train loss: 0.1240  mean_iou: 0.8770
# [Epoch 18: 170/200] train loss: 0.1254  mean_iou: 0.8755
# [Epoch 18: 180/200] train loss: 0.1350  mean_iou: 0.8661
# [Epoch 18: 190/200] train loss: 0.2064  mean_iou: 0.7969
# [Epoch 18: 200/200] train loss: 0.1244  mean_iou: 0.8765
# ... validate epoch 18 ...
# average loss: 0.1092
# average iou: 0.8915
# ..............................
# [Epoch 19: 10/200] train loss: 0.1576  mean_iou: 0.8442
# [Epoch 19: 20/200] train loss: 0.1342  mean_iou: 0.8669
# [Epoch 19: 30/200] train loss: 0.1247  mean_iou: 0.8762
# [Epoch 19: 40/200] train loss: 0.2021  mean_iou: 0.8011
# [Epoch 19: 50/200] train loss: 0.2010  mean_iou: 0.8020
# [Epoch 19: 60/200] train loss: 0.1704  mean_iou: 0.8316
# [Epoch 19: 70/200] train loss: 0.1302  mean_iou: 0.8709
# [Epoch 19: 80/200] train loss: 0.2447  mean_iou: 0.7601
# [Epoch 19: 90/200] train loss: 0.1389  mean_iou: 0.8624
# [Epoch 19: 100/200] train loss: 0.1543  mean_iou: 0.8473
# [Epoch 19: 110/200] train loss: 0.1230  mean_iou: 0.8779
# [Epoch 19: 120/200] train loss: 0.1558  mean_iou: 0.8460
# [Epoch 19: 130/200] train loss: 0.1518  mean_iou: 0.8498
# [Epoch 19: 140/200] train loss: 0.1431  mean_iou: 0.8582
# [Epoch 19: 150/200] train loss: 0.1602  mean_iou: 0.8417
# [Epoch 19: 160/200] train loss: 0.1421  mean_iou: 0.8592
# [Epoch 19: 170/200] train loss: 0.1403  mean_iou: 0.8609
# [Epoch 19: 180/200] train loss: 0.2169  mean_iou: 0.7869
# [Epoch 19: 190/200] train loss: 0.1401  mean_iou: 0.8612
# [Epoch 19: 200/200] train loss: 0.1627  mean_iou: 0.8392
# ... validate epoch 19 ...
# average loss: 0.1207
# average iou: 0.8801
# ..............................
# [Epoch 20: 10/200] train loss: 0.1928  mean_iou: 0.8106
# [Epoch 20: 20/200] train loss: 0.1236  mean_iou: 0.8774
# [Epoch 20: 30/200] train loss: 0.2468  mean_iou: 0.7582
# [Epoch 20: 40/200] train loss: 0.1452  mean_iou: 0.8562
# [Epoch 20: 50/200] train loss: 0.2051  mean_iou: 0.7980
# [Epoch 20: 60/200] train loss: 0.1397  mean_iou: 0.8616
# [Epoch 20: 70/200] train loss: 0.1827  mean_iou: 0.8196
# [Epoch 20: 80/200] train loss: 0.1352  mean_iou: 0.8660
# [Epoch 20: 90/200] train loss: 0.2165  mean_iou: 0.7871
# [Epoch 20: 100/200] train loss: 0.1186  mean_iou: 0.8822
# [Epoch 20: 110/200] train loss: 0.1924  mean_iou: 0.8102
# [Epoch 20: 120/200] train loss: 0.1301  mean_iou: 0.8710
# [Epoch 20: 130/200] train loss: 0.1542  mean_iou: 0.8474
# [Epoch 20: 140/200] train loss: 0.1835  mean_iou: 0.8189
# [Epoch 20: 150/200] train loss: 0.1657  mean_iou: 0.8363
# [Epoch 20: 160/200] train loss: 0.1633  mean_iou: 0.8386
# [Epoch 20: 170/200] train loss: 0.1595  mean_iou: 0.8424
# [Epoch 20: 180/200] train loss: 0.1480  mean_iou: 0.8537
# [Epoch 20: 190/200] train loss: 0.1609  mean_iou: 0.8410
# [Epoch 20: 200/200] train loss: 0.1380  mean_iou: 0.8633
# ... validate epoch 20 ...
# average loss: 0.1516
# average iou: 0.8500
# ..............................
